# %% [markdown]
# #### Answer Columns
# * answers_columns[0]   - ID
# * answers_columns[1]   - Tidstämpel
# * answers_columns[2]   - Highest level of education
# * answers_columns[3]   - Experience of software development (in years)
# * answers_columns[4]   - Current occupation
# * answers_columns[5]   - Role and previous experience
# * answers_columns[6]   - Programming best practices
# * answers_columns[7]   - What programming languages are you able to use proficiently?
# * answers_columns[8]   - What programming languages do you use the most?
# * answers_columns[9]   - Are you aware of the term clean code?
# * answers_columns[10]  - Define what clean code is to you
# * answers_columns[11]  - Do you have dyslexia or any other reading disorder?
# * answers_columns[12]  - Length of lines of code
# * answers_columns[13]  - Usage of numbers directly in the source code, opposed to first encapsulating it within a constant or a variable
# * answers_columns[14]  - Writing code in a format that is consistent with the previous code
# * answers_columns[15]  - Usage of comments
# * answers_columns[16]  - Writing all comments on own lines (No trailing comments)
# * answers_columns[17]  - Nesting loops or if-statements
# * answers_columns[18]  - Usage of arithmetic formula directly in the source code, opposed to encapsulating it within a function.
# * answers_columns[19]  - Defining all variables at the top of the method/function, opposed to defining the variable as close to the first reference as possible
# * answers_columns[20]  - Usage of Hungarian notation
# * answers_columns[21]  - Names with full words found in dictionaries
# * answers_columns[22]  - Commonly used abbreviations such as “txt”, “msg”, “cnt” or “retVal”
# * answers_columns[23]  - What naming style do you think is easiest to read?
# * answers_columns[24]  - Do you think giving constant variables SCREAMING_SNAKE_CASE names increases readability?
# * answers_columns[25]  - When I have completed a task and commit the code into a repository, I always feel that the code is refactored and written as readable and clean as I possibly can.
# * answers_columns[26]  - What are the reasons for committing code that you are not fully satisfied with?
# * answers_columns[27]  - What activities do/would help you write readable and clean code?
# #### Naming Style Columns
# * naming_style_columns[0] - ID
# * naming_style_columns[1] - Choise
# * naming_style_columns[2] - Code
#
# #### Role Columns
# * role_columns[0] - ID
# * role_columns[1] - I frequently write code
# * role_columns[2] - I frequently debug code written by others/legacy code
# * role_columns[3] - I frequently review others code
# * role_columns[4] - None of the above
#
# #### Known Languages
# * known_languages_columns[0]  - ID
# * known_languages_columns[1]  - ADA
# * known_languages_columns[2]  - Apache Groovy
# * known_languages_columns[3]  - Assembly language
# * known_languages_columns[4]  - AWK
# * known_languages_columns[5]  - Bash
# * known_languages_columns[6]  - BitBake
# * known_languages_columns[7]  - C
# * known_languages_columns[8]  - C#
# * known_languages_columns[9]  - C++
# * known_languages_columns[10]  - Clojure
# * known_languages_columns[11]  - Dart
# * known_languages_columns[12]  - Eifel
# * known_languages_columns[13]  - Elixir
# * known_languages_columns[14]  - Erlang
# * known_languages_columns[15]  - F#
# * known_languages_columns[16]  - Flutter
# * known_languages_columns[17]  - Fortran
# * known_languages_columns[18]  - GO
# * known_languages_columns[19]  - Hack
# * known_languages_columns[20]  - Haskell
# * known_languages_columns[21]  - Hlsl
# * known_languages_columns[22]  - Java
# * known_languages_columns[23]  - JavaScript
# * known_languages_columns[24]  - Kotlin
# * known_languages_columns[25]  - lisp
# * known_languages_columns[26]  - Lua
# * known_languages_columns[27]  - MATLAB
# * known_languages_columns[28]  - Modula3
# * known_languages_columns[29]  - Object Pascal
# * known_languages_columns[30]  - Object-C
# * known_languages_columns[31]  - Perl
# * known_languages_columns[32]  - PHP
# * known_languages_columns[33]  - PostScript
# * known_languages_columns[34]  - Python
# * known_languages_columns[35]  - R
# * known_languages_columns[36]  - Ruby
# * known_languages_columns[37]  - Rust
# * known_languages_columns[38]  - Scala
# * known_languages_columns[39]  - Sh
# * known_languages_columns[40]  - SQL
# * known_languages_columns[41]  - Swift
# * known_languages_columns[42]  - tcl
# * known_languages_columns[43]  - Typescript
# * known_languages_columns[44]  - Visual Basic
# * known_languages_columns[45]  - X++
#
# #### Working Languages
# * working_languages_columns[0]  - ID
# * working_languages_columns[1]  - ADA
# * working_languages_columns[2]  - Apache Groovy
# * working_languages_columns[3]  - Assembly language
# * working_languages_columns[4]  - AWK
# * working_languages_columns[5]  - Bash
# * working_languages_columns[6]  - BitBake
# * working_languages_columns[7]  - C
# * working_languages_columns[8]  - C#
# * working_languages_columns[9]  - C++
# * working_languages_columns[10] - Clojure
# * working_languages_columns[11] - Dart
# * working_languages_columns[12] - Eifel
# * working_languages_columns[13] - Elixir
# * working_languages_columns[14] - Erlang
# * working_languages_columns[15] - F#
# * working_languages_columns[16] - Flutter
# * working_languages_columns[17] - Fortran
# * working_languages_columns[18] - GO
# * working_languages_columns[19] - Hack
# * working_languages_columns[20] - Haskell
# * working_languages_columns[21] - Hlsl
# * working_languages_columns[22] - Java
# * working_languages_columns[23] - JavaScript
# * working_languages_columns[24] - Kotlin
# * working_languages_columns[25] - lisp
# * working_languages_columns[26] - Lua
# * working_languages_columns[27] - MATLAB
# * working_languages_columns[28] - Modula3
# * working_languages_columns[29] - Object Pascal
# * working_languages_columns[30] - Object-C
# * working_languages_columns[31] - Perl
# * working_languages_columns[32] - PHP
# * working_languages_columns[33] - PostScript
# * working_languages_columns[34] - Python
# * working_languages_columns[35] - R
# * working_languages_columns[36] - Ruby
# * working_languages_columns[37] - Rust
# * working_languages_columns[38] - Scala
# * working_languages_columns[39] - Sh
# * working_languages_columns[40] - SQL
# * working_languages_columns[41] - Swift
# * working_languages_columns[42] - tcl
# * working_languages_columns[43] - Typescript
# * working_languages_columns[44] - Visual Basic
# * working_languages_columns[45] - X++
#
# # Reasons For Bad Code
# * reasons_for_bad_code_columns[0]   - ID
# * reasons_for_bad_code_columns[1]   - What are the reasons for committing code that you are not fully satisfied with?
# * reasons_for_bad_code_columns[2]   - Lack of planning
# * reasons_for_bad_code_columns[3]   - Lack of interest
# * reasons_for_bad_code_columns[4]   - Lack of training or knowledge
# * reasons_for_bad_code_columns[5]   - Unrealistic schedule
# * reasons_for_bad_code_columns[6]   - Too small budget
# * reasons_for_bad_code_columns[7]   - Code readability is not considered as a concern in my organisation/team
# * reasons_for_bad_code_columns[8]   - Writing clean and readable code is not encouraged in my team/organisation
# * reasons_for_bad_code_columns[9]   - Not worth the effort
# * reasons_for_bad_code_columns[10]  - Working with legacy code
# * reasons_for_bad_code_columns[11]  - Missed self-review before commit
# * reasons_for_bad_code_columns[12]  - I, or someone else will clean up later
# * reasons_for_bad_code_columns[13]  - POC/Prototype/Experiment
# * reasons_for_bad_code_columns[14]  - Other
#
# #### Helping Activities
# * helping_activities_columns[0]    - ID
# * helping_activities_columns[1]    - Activities
# * helping_activities_columns[2]    - Self-review
# * helping_activities_columns[3]    - Better Design
# * helping_activities_columns[4]    - Better tools
# * helping_activities_columns[5]    - Code reviews
# * helping_activities_columns[6]    - Education and seminars
# * helping_activities_columns[7]    - Experience
# * helping_activities_columns[8]    - Mob programming.
# * helping_activities_columns[9]    - More time
# * helping_activities_columns[10]    - No legacy code to interact with.
# * helping_activities_columns[11]    - Pair programming
# * helping_activities_columns[12]    - Choise of language
# * helping_activities_columns[13]    - Requirements in CI
# * helping_activities_columns[14]    - Clearer standards
# * helping_activities_columns[15]    - Writing an alternative implementation
#
# #### Best Practices
# * best_practices_columns[0]   - ID
# * best_practices_columns[1]   - Code standard
# * best_practices_columns[2]   - Naming conventions
# * best_practices_columns[3]   - DRY
# * best_practices_columns[4]   - Linters
# * best_practices_columns[5]   - Comments
# * best_practices_columns[6]   - No Comments at all
# * best_practices_columns[7]   - Standard formatting
# * best_practices_columns[8]   - Code reviews
# * best_practices_columns[9]   - Testing
# * best_practices_columns[10]  - TDD
# * best_practices_columns[11]  - Clean code
# * best_practices_columns[12]  - Externaly defined code standard
# * best_practices_columns[13]  - Static analysis
# * best_practices_columns[14]  - SOLID
# * best_practices_columns[15]  - KISS
# * best_practices_columns[16]  - SoC
# * best_practices_columns[17]  - YAGNI
# * best_practices_columns[18]  - CI/CD
# * best_practices_columns[19]  - Mob programming
# * best_practices_columns[20]  - Pair programming
#
# #### Clean Code Definitions
# * clean_code_def_columns[0]   - ID
# * clean_code_def_columns[1]   - Clear/Meaningful names
# * clean_code_def_columns[2]   - Correct and consistent Indentation
# * clean_code_def_columns[3]   - Structure
# * clean_code_def_columns[4]   - Easy to read
# * clean_code_def_columns[5]   - Easy to understand
# * clean_code_def_columns[6]   - Easy to modify/refactor
# * clean_code_def_columns[7]   - Easy to reuse
# * clean_code_def_columns[8]   - Easy to maintain
# * clean_code_def_columns[9]   - Easy to test
# * clean_code_def_columns[10]   - "Describing" code
# * clean_code_def_columns[11]   - No Side effects
# * clean_code_def_columns[12]   - KISS
# * clean_code_def_columns[13]   - SOLID
# * clean_code_def_columns[14]   - DRY
# * clean_code_def_columns[15]   - SoC
# * clean_code_def_columns[16]   - YAGNI
# * clean_code_def_columns[17]   - Short functions/classes
# * clean_code_def_columns[18]   - Reusability
# * clean_code_def_columns[19]   - Low coupling/High cohesion
# * clean_code_def_columns[20]   - Encapsulation
# * clean_code_def_columns[21]   - Consistency
# * clean_code_def_columns[22]   - Hungarian Notation
# * clean_code_def_columns[23]   - Carefully chosen comments
# * clean_code_def_columns[24]   - Don't mix abstraction level

# %%
import pandas as pd
import numpy as np
import plot_likert
import matplotlib as mpl
from matplotlib import pyplot as plt
from function import get_dataframe, plot_likert_data, get_likert_questions, filter, filter_on_values_from_sheet

mpl.rcParams['ytick.labelsize'] = 12

# %%
answers, naming_style, role, known_languages, working_languages, \
    reasons_for_bad_code, helping_activities, best_practices, clean_code_def = get_dataframe()
answers_columns = list(answers.columns)
naming_style_columns = list(naming_style.columns)
role_columns = list(role.columns)
known_languages_columns = list(known_languages.columns)
working_languages_columns = list(working_languages.columns)
reasons_for_bad_code_columns = list(reasons_for_bad_code.columns)
helping_activities_columns = list(helping_activities.columns)
best_practices_columns = list(best_practices.columns)
clean_code_def_columns = list(clean_code_def.columns)
# Out:
# 9       10
# 167    168
# Name: ID, dtype: int64

# %%
developers = filter(answers, [answers_columns[4]], [['Developer']])
developers_lt_5_years= developers.loc[developers[answers_columns[3]] <= 5]
developers_gte_20_years= developers.loc[developers[answers_columns[3]] >= 20]

plot_likert_data(get_likert_questions(developers_lt_5_years))

# %%
students = filter(answers, [answers_columns[4]], [['Student']])
no_clean_code = filter(answers, [answers_columns[9]], [['No']])
dys = filter(answers, [answers_columns[11]], [['Yes']])
ndys = filter(answers, [answers_columns[11]], [['Yes']], True)
not_students = filter(answers, [answers_columns[4]], [['Student']], True)

plot_likert_data(get_likert_questions(answers))
get_likert_questions(answers).range()
# Out:
# c:\Users\isacm\AppData\Local\Programs\Python\Python39\lib\site-packages\plot_likert\plot_likert.py:299: UserWarning: In your data, not all questions have the same number of responses. i.e., different numbers of people answered each question. Therefore, the percentages aren't directly comparable: X% for one question represents a different number of responses than X% for another question, yet they will appear the same in the percentage graph. This may be misleading to your reader.
#   warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25480/2649346195.py in <module>
#       6
#       7 plot_likert_data(get_likert_questions(answers))
# ----> 8 get_likert_questions(answers).range()
#
# c:\Users\isacm\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
# ...

# %%
a = clean_code_def.loc[clean_code_def['ID'].isin(developers_lt_5_years['ID'])].count().sort_values(ascending=False).drop(["ID"])
b = clean_code_def.loc[clean_code_def['ID'].isin(developers_gte_20_years['ID'])].count().sort_values(ascending=False).drop(["ID"])

clean_code_def.count().sort_values(ascending=False).drop(["ID"]).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19460/2865996353.py in <module>
# ----> 1 a = clean_code_def.loc[clean_code_def['ID'].isin(developers_lt_5_years['ID'])].count().sort_values(ascending=False).drop(["ID"])
#       2 b = clean_code_def.loc[clean_code_def['ID'].isin(developers_gte_20_years['ID'])].count().sort_values(ascending=False).drop(["ID"])
#       3
#       4 clean_code_def.count().sort_values(ascending=False).drop(["ID"]).plot.bar()
#
# NameError: name 'clean_code_def' is not defined

# %%
c = a.plot.bar()

# %%
# answers[answers_columns[11]].value_counts().plot.pie(autopct='%.2f', figsize=(8,8), fontsize=14) 
bp = clean_code_def.count().drop('ID').sort_values(ascending=False)

head = bp.sort_values(ascending=True)

head.plot.barh(figsize=(6,6), fontsize=12) 
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
plot_likert_data(get_likert_questions(answers.loc[answers[answers_columns[11]] == 'Yes']))

# %%
plot_likert_data(get_likert_questions(answers.loc[answers[answers_columns[11]] != 'Yes']))
# Out:
# c:\Users\isacm\AppData\Local\Programs\Python\Python39\lib\site-packages\plot_likert\plot_likert.py:299: UserWarning: In your data, not all questions have the same number of responses. i.e., different numbers of people answered each question. Therefore, the percentages aren't directly comparable: X% for one question represents a different number of responses than X% for another question, yet they will appear the same in the percentage graph. This may be misleading to your reader.
#   warn(

# %%
print((working_languages.count()/known_languages.count()).sort_values(ascending=False))
print(known_languages.count())
print(working_languages.count())
# Out:
# X++                       inf
# BitBake              1.000000
# Hack                 1.000000
# Erlang               1.000000
# Dart                 1.000000
# Clojure              1.000000
# ID                   1.000000
# Rust                 0.888889
# Typescript           0.846154
# Sh                   0.800000
# Bash                 0.750000
# Ruby                 0.727273
# Kotlin               0.700000
# C#                   0.677778
# JavaScript           0.561538
# GO                   0.529412
# Java                 0.525773
# Fortran              0.500000
# Python               0.446602
# C++                  0.386667
# PHP                  0.342105
# F#                   0.333333
# SQL                  0.321101
# Swift                0.300000
# Scala                0.250000
# C                    0.250000
# Elixir               0.250000
# Apache Groovy        0.250000
# Object Pascal        0.200000
# Perl                 0.181818
# Haskell              0.166667
# ...

# %%
question_nr = 19

print(answers_columns[question_nr])
c = answers[answers_columns[question_nr]].value_counts()

total = c[1]+c[2]+c[3]+c[4]+c[5]+c[6]+c[7]
print(total)

plot_likert_data(answers[answers_columns[question_nr]], size=(10,2))
print(f"Positive: {round(100*(c[5]+c[6]+c[7])/total,3)}")
print(f"Neutral: {round(100*(c[4])/total,3)}")
print(f"Negative: {round(100*(c[1]+c[2]+c[3])/total,3)}")
# Out:
# Defining all variables at the top of the method/function, opposed to defining the variable as close to the first reference as possible
# 198
# Positive: 25.253
# Neutral: 20.707
# Negative: 54.04

# %%
question_nr = 20

print(answers_columns[question_nr])
c = answers[answers_columns[question_nr]].value_counts()

total = c[1]+c[2]+c[3]+c[4]+c[5]+c[6]+c[7]
print(total)

plot_likert_data(answers[answers_columns[question_nr]], size=(10,2))
print(f"Positive: {round(100*(c[5]+c[6]+c[7])/total,3)}")
print(f"Neutral: {round(100*(c[4])/total,3)}")
print(f"Negative: {round(100*(c[1]+c[2]+c[3])/total,3)}")
# Out:
# Usage of Hungarian notation
# 198
# Positive: 16.667
# Neutral: 22.727
# Negative: 60.606

# %%
question_nr = 21

print(answers_columns[question_nr])
c = answers[answers_columns[question_nr]].value_counts()

total = c[1]+c[2]+c[3]+c[4]+c[5]+c[6]+c[7]
print(total)

plot_likert_data(answers[answers_columns[question_nr]], size=(10,2))
print(f"Positive: {round(100*(c[5]+c[6]+c[7])/total,3)}")
print(f"Neutral: {round(100*(c[4])/total,3)}")
print(f"Negative: {round(100*(c[1]+c[2]+c[3])/total,3)}")
# Out:
# Names with full words found in dictionaries
# 198
# Positive: 73.232
# Neutral: 19.192
# Negative: 7.576

# %%
question_nr = 22

print(answers_columns[question_nr])
c = answers[answers_columns[question_nr]].value_counts()

total = c[1]+c[2]+c[3]+c[4]+c[5]+c[6]+c[7]
print(total)

plot_likert_data(answers[answers_columns[question_nr]], size=(10,2))
print(f"Positive: {round(100*(c[5]+c[6]+c[7])/total,3)}")
print(f"Neutral: {round(100*(c[4])/total,3)}")
print(f"Negative: {round(100*(c[1]+c[2]+c[3])/total,3)}")
# Out:
# Commonly used abbreviations such as “txt”, “msg”, “cnt” or “retVal”
# 198
# Positive: 40.404
# Neutral: 21.717
# Negative: 37.879

# %%
question_nr = 24

print(answers_columns[question_nr])
c = answers[answers_columns[question_nr]].value_counts()

c.plot.pie(label="", autopct='%.2f', figsize=(5,5), fontsize=12)
# Out:
# Do you think giving constant variables SCREAMING_SNAKE_CASE names increases readability?
# <AxesSubplot:>
